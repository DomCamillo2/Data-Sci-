# %% [markdown]
# # 02 — Second annotator (Ollama)
#
# Labels SpaCy tokens. Scientific analysis of **loci** is notebook 03.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))
# Prefer: !python ../scripts/run_llm_annotate.py --lang both
# Pilot: !python ../scripts/run_llm_annotate.py --lang de --limit 5
print('Use scripts/run_llm_annotate.py for resumable batch annotation.')
