# %% [markdown]
# # 03 — Linguistic loci analysis
#
# H1: per-UPOS disagreement
# H2: DE vs EN profiles
# H3: overall agreement as summary

# %%
import pandas as pd
from pathlib import Path
ROOT = Path('..').resolve()
# After annotation exists:
# de = pd.read_csv(ROOT/'data/processed/annotations_de.csv')
# en = pd.read_csv(ROOT/'data/processed/annotations_en.csv')
print('Load annotations_* after Phase 3.')
